# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiyaMer/102117045-SESS_LE1/blob/main/about-lab-eval/102117045-ShiyaMer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: **Shiya Mer**
# Email: `smer_be21@thapar.edu`
# Roll No: **10217045**
# Group: **4CS1**
# Start Timestamp: YYYYMMDD-HHMM

# %% [markdown]
# ## Question
#
#   Consider the paper: <https://arxiv.org/abs/1804.03209>
#
#   1. Read and summarise the paper in about 50 words.
#   2. Download the dataset in the paper, statistically analyse and
#      describe it, so that it may be useful for posterity. (Include code
#      snippets in your .ipynb file to evidence your analysis.)
#   3. Train a classifier so that you are able to distinguish the commands
#      in the dataset.
#   4. Report the performance results using standard benchmarks.
#   5. Record about 30 samples of each command in your voice and create a
#      new dataset (including a new user id for yourself).  You may use a
#      timer on your computer to synchronise.
#   6. Fine tune your classifier to perform on your voice.
#   7. Report the results.

# %% [markdown]
# ## Solution

# %% [markdown]
# ##**Paper Summary**
#
#
# **Speech Commands: A Dataset for Limited-Vocabulary Speech
# Recognition**
#
#
# **->What the paper is trying to do:**
# * Make a standard dataset for keyword spotting(i.e importance to individual words not sentence as whole)
#
#
#  **->Dataset:**
#
#
# *   Dataset captured through phone to account for noise
# *   Lang:English
# *   Duration:1s
# *   Vocab:"Yes", "No", "Up", "Down", "Left", "Right","On", "Off", "Stop", and "Go",“Backward”, “Forward”, “Follow”, and “Learn”
#
# **->Implementation:**
#
# 1. Procure Dataset
# 2. Quality check by deletion of smaller files
# 3. Extract of loudest section
# 4. Add Background Noise
# 5. Trained on CNN(Version 1 and Vesion2)
# 6. Metrics:Top One Score
#
# **Challenges:**
#
# *   Ignoring speech that doesn’t contain triggers

# %% [markdown]
# ##DATASET DOWNLOAD
#
# https://drive.google.com/drive/folders/10-1-WQUiaRFGj-jFNpSP6cqTwVGFlGHZ?usp=drive_link

# %% [markdown]
# ##**Purpose**
# ##SPEECH HELPLINE
# To train a speech model that will recognise 112 that is a emergency number
# and recognise yes and no to proceed with calling or not.
# For the above process i have extracted a subset i.e(one,two,yes,no)

# %% [markdown]
# Custom Dataset:
# All data was recorded and converetd from m4a files to wav files
#
# Link to dataset: https://huggingface.co/datasets/ShiyaMer/112DataSet

# %% [markdown]
# Model Used:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Google Drive Link:
# https://drive.google.com/drive/folders/10-1-WQUiaRFGj-jFNpSP6cqTwVGFlGHZ?usp=drive_link

# %% [markdown]
# Colab Notebook Link:
# https://colab.research.google.com/drive/1fu7Zf7lTDRr2TGtT0V88Um0mH4UPoNhp?usp=drive_link

# %% [markdown]
# ## Test Case
